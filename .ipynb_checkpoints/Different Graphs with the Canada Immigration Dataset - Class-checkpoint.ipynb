# %% [markdown]
# # Preamble: Data Prep

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\lecturer\anaconda3\envs\p312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\lecturer\anaconda3\envs\p312\lib\site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_excel('Canada.xlsx', 
                       sheet_name = "Canada by Citizenship",
                       skipfooter = 2,
                       skiprows = range(20))
dataset.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# 2  3623  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0     0
# 4     1     0     0     0     0     1     1
#
# [5 rows x 43 columns]

# %%
dataset.drop(['AREA','REG','DEV'], axis=1, inplace=True)
dataset.head()
# Out:
#          Type    Coverage          OdName AreaName          RegName  \
# 0  Immigrants  Foreigners     Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria   Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa  Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra   Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
# 4   Developed regions     0     0     0     0  ...     0     0     1     1
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# 1   560   716   561   539   620   603
# 2  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0
# 4     0     0     0     0     1     1
#
# [5 rows x 40 columns]

# %%
dataset['Total'] = dataset.sum(axis=1, numeric_only=True)
dataset.head()
# Out:
#          Type    Coverage          OdName AreaName          RegName  \
# 0  Immigrants  Foreigners     Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria   Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa  Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra   Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39    47  ...  3436  3009  2652  2111
# 1   Developed regions     1     0     0     0  ...  1223   856   702   560
# 2  Developing regions    80    67    71    69  ...  3626  4807  3623  4005
# 3  Developing regions     0     1     0     0  ...     0     1     0     0
# 4   Developed regions     0     0     0     0  ...     0     1     1     0
#
#    2009  2010  2011  2012  2013  Total
# 0  1746  1758  2203  2635  2004  58639
# 1   716   561   539   620   603  15699
# 2  5393  4752  4325  3774  4331  69439
# 3     0     0     0     0     0      6
# 4     0     0     0     1     1     15
#
# [5 rows x 41 columns]

# %%
dataset.set_index('OdName', inplace=True)

# %%
#Checking a particular row
print(dataset.loc['Haiti'])
# Out:
# Type                             Immigrants
# Coverage                         Foreigners
# AreaName    Latin America and the Caribbean
# RegName                           Caribbean
# DevName                  Developing regions
# 1980                                   1666
# 1981                                   3692
# 1982                                   3498
# 1983                                   2860
# 1984                                   1418
# 1985                                   1321
# 1986                                   1753
# 1987                                   2132
# 1988                                   1829
# 1989                                   2377
# 1990                                   2379
# 1991                                   2829
# 1992                                   2399
# 1993                                   3655
# 1994                                   2100
# 1995                                   2014
# 1996                                   1955
# 1997                                   1645
# 1998                                   1295
# 1999                                   1439
# 2000                                   1631
# 2001                                   2433
# 2002                                   2174
# 2003                                   1930
# 2004                                   1652
# 2005                                   1682
# 2006                                   1619
# 2007                                   1598
# 2008                                   2491
# 2009                                   2080
# 2010                                   4744
# 2011                                   6503
# 2012                                   5868
# 2013                                   4152
# Total                                 84813
# Name: Haiti, dtype: object

# %%
#Checking a particular year and a particular row

print(dataset.loc['Haiti', 2013])
# Out:
# 4152

# %%
#Converting the years to string
dataset.columns = list(map(str, dataset.columns))
[print (type(x)) for x in dataset.columns.values]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#Creating the range of years
years = list (map(str, range(1980, 2014)))

# %%
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# # Line Plot
# ### Uses
# Good with continuous data.
# Good for showing trends over time.
#
# ### Tips
# Try to use solid lines.
#
# Points should be conisitantly ordered.
#
# Label lines directly.
#
# Don't plot too many lines at once.
#
# Try to include the 0 base.

# %%
#LINE PLOT - IMMIGRATION FROM HAITI

dataset.loc['Haiti', years].plot(kind = 'line', color = 'red')
plt.title('Immigrants from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.show();

# %%
#ADD TEXT TO EXPLAIN THE SPIKE

dataset.loc['Haiti', years].plot(kind = 'line', color = 'red')
plt.title('Immigrants from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.text(20, 6000, '2010 Earthquake')

plt.show()

# %%
dataset.loc['Haiti', years].plot(kind = 'line', color = 'red')
dataset.loc['Argentina', years].plot(kind = 'line', color = 'blue')
plt.title('Immigrants from Haiti vs Argentina')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')
plt.legend(['Haiti', 'Argentina'])
plt.show()

# %% [markdown]
# # Pie Chart
# ### Uses
# Show proportions ie vote shares in elections.
# Illustrate a breakdown of a set.
#
# ### Tips
# Try not to have too many slices.
#
# Make sure it totals to 100%.
#
# Make the most important stand out, where relevant.
#
# Order the slices carefully.

# %%
dataset["AreaName"]
# Out:
# OdName
# India                                                      Asia
# China                                                      Asia
# United Kingdom of Great Britain and Northern Ireland     Europe
# Philippines                                                Asia
# Pakistan                                                   Asia
#                                                          ...
# New Caledonia                                           Oceania
# San Marino                                               Europe
# Marshall Islands                                        Oceania
# Western Sahara                                           Africa
# Palau                                                   Oceania
# Name: AreaName, Length: 195, dtype: object

# %%
#PIE CHART

data_continents = dataset.groupby('AreaName', axis = 0).sum()


data_continents['Total'].plot(kind='pie')


plt.title('Immigration by Areas [1980-2013]')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lecturer\AppData\Local\Temp\ipykernel_8036\639711037.py:3: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   data_continents = dataset.groupby('AreaName', axis = 0).sum()

# %%
#PIE CHART

data_continents = dataset.groupby('AreaName', axis = 0).sum()

data_continents['Total'].plot(kind='pie', radius=.5, autopct='%1.0f%%')

plt.title('Immigration by Areas [1980-2013]', fontsize = 12)
plt.tight_layout()
plt.show();
# Out:
# C:\Users\Lecturer\AppData\Local\Temp\ipykernel_8036\1209957303.py:3: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   data_continents = dataset.groupby('AreaName', axis = 0).sum()

# %%
#PIE CHART
#Explode a slice
data_continents = dataset.groupby('AreaName', axis = 0).sum()
data_continents
# Out:
# C:\Users\Lecturer\AppData\Local\Temp\ipykernel_8036\1696819170.py:3: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   data_continents = dataset.groupby('AreaName', axis = 0).sum()
#                                                                               Type  \
# AreaName
# Africa                           ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
# Asia                             ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
# Europe                           ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
# Latin America and the Caribbean  ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
# Northern America                                              ImmigrantsImmigrants
# Oceania                          ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
#
#                                                                           Coverage  \
# AreaName
# Africa                           ForeignersForeignersForeignersForeignersForeig...
# Asia                             ForeignersForeignersForeignersForeignersForeig...
# Europe                           ForeignersForeignersForeignersForeignersForeig...
# Latin America and the Caribbean  ForeignersForeignersForeignersForeignersForeig...
# Northern America                                                CitizensForeigners
# Oceania                          ForeignersForeignersForeignersForeignersForeig...
#
#                                                                            RegName  \
# AreaName
# Africa                           Northern AfricaMiddle AfricaWestern AfricaSout...
# Asia                             Southern AsiaWestern AsiaWestern AsiaWestern A...
# Europe                           Southern EuropeSouthern EuropeWestern EuropeEa...
# Latin America and the Caribbean  CaribbeanSouth AmericaCaribbeanCaribbeanCentra...
# Northern America                                  Northern AmericaNorthern America
# Oceania                          PolynesiaAustralia and New ZealandMelanesiaMic...
#
#                                                                            DevName  \
# AreaName
# Africa                           Developing regionsDeveloping regionsDeveloping...
# Asia                             Developing regionsDeveloping regionsDeveloping...
# Europe                           Developed regionsDeveloped regionsDeveloped re...
# Latin America and the Caribbean  Developing regionsDeveloping regionsDeveloping...
# Northern America                                Developed regionsDeveloped regions
# Oceania                          Developing regionsDeveloped regionsDeveloping ...
#
#                                   1980   1981   1982   1983   1984   1985  \
# AreaName
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                  ...    2005    2006    2007    2008    2009  \
# AreaName                         ...
# Africa                           ...   27523   29188   28284   29890   34534
# Asia                             ...  159253  149054  133459  139894  141434
# Europe                           ...   35955   33053   33495   34692   35078
# Latin America and the Caribbean  ...   24747   24676   26011   26547   26867
# Northern America                 ...    8394    9613    9463   10190    8995
# Oceania                          ...    1585    1473    1693    1834    1860
#
#                                    2010    2011    2012    2013    Total
# AreaName
# Africa                            40892   35441   38083   38543   618948
# Asia                             163845  146894  152218  155075  3317794
# Europe                            33425   26778   29177   28691  1410947
# Latin America and the Caribbean   28818   27856   27173   24950   765148
# Northern America                   8142    7677    7892    8503   241142
# Oceania                            1834    1548    1679    1775    55174
#
# [6 rows x 39 columns]

# %%
list(data_continents.index).index("Latin America and the Caribbean")
# Out:
# 3

# %%
#PIE CHART
#Explode a slice

data_continents = dataset.groupby('AreaName', axis = 0).sum()
explode = (0, 0, 0, 0.5, 0, 0)
data_continents['Total'].plot(kind='pie', radius=1.2, autopct='%1.1f%%', explode = explode, shadow = True)

plt.title('Immigration by Areas [1980-2013]')
plt.tight_layout()
plt.show();
# Out:
# C:\Users\Lecturer\AppData\Local\Temp\ipykernel_8036\100655355.py:4: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   data_continents = dataset.groupby('AreaName', axis = 0).sum()

# %%
#PIE CHART
#Explode a slice

data_continents = dataset.groupby('AreaName', axis = 0).sum()
explode = (0.2, 0, 0.2, 0, 0, 0)
data_continents['Total'].plot(kind='pie', radius=1.2, autopct='%1.1f%%', explode = explode, shadow = True)

plt.title('Immigration by Areas [1980-2013]')
plt.tight_layout()
plt.show();
# Out:
# C:\Users\Lecturer\AppData\Local\Temp\ipykernel_8036\2726034248.py:4: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   data_continents = dataset.groupby('AreaName', axis = 0).sum()

# %% [markdown]
# # Area Plots
# ### Uses
# Show how proportions or make-up changes over time.
#
# ### Tips
# Try not to display too many categories.
#
# Carefully order the categories.

# %%
#AREA PLOTS
#We sort the values from the largest to the smallest

dataset.sort_values(['Total'], ascending = False, axis = 0, inplace = True)
dataset.head()
# Out:
#                                                           Type    Coverage  \
# OdName
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
#
#                                                    AreaName  \
# OdName
# India                                                  Asia
# China                                                  Asia
# United Kingdom of Great Britain and Northern Ir...   Europe
# Philippines                                            Asia
# Pakistan                                               Asia
#
#                                                                RegName  \
# OdName
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# OdName
# India                                               Developing regions   8880
# China                                               Developing regions   5123
# United Kingdom of Great Britain and Northern Ir...   Developed regions  22045
# Philippines                                         Developing regions   6051
# Pakistan                                            Developing regions    978
#
#                                                      1981   1982   1983  \
# OdName
# India                                                8670   8147   7338
# China                                                6682   3308   1863
# United Kingdom of Great Britain and Northern Ir...  24796  20620  10015
# Philippines                                          5921   5249   4562
# Pakistan                                              972   1201    900
#
#                                                      1984  ...   2005   2006  \
# OdName                                                     ...
# India                                                5704  ...  36210  33848
# China                                                1527  ...  42584  33518
# United Kingdom of Great Britain and Northern Ir...  10170  ...   7258   7140
# Philippines                                          3801  ...  18139  18400
# Pakistan                                              668  ...  14314  13127
#
#                                                      2007   2008   2009  \
# OdName
# India                                               28742  28261  29456
# China                                               27642  30037  29622
# United Kingdom of Great Britain and Northern Ir...   8216   8979   8876
# Philippines                                         19837  24887  28573
# Pakistan                                            10124   8994   7217
#
#                                                      2010   2011   2012  \
# OdName
# India                                               34235  27509  30933
# China                                               30391  28502  33024
# United Kingdom of Great Britain and Northern Ir...   8724   6204   6195
# Philippines                                         38617  36765  34315
# Pakistan                                             6811   7468  11227
#
#                                                      2013   Total
# OdName
# India                                               33087  691904
# China                                               34129  659962
# United Kingdom of Great Britain and Northern Ir...   5827  551500
# Philippines                                         29544  511391
# Pakistan                                            12603  241600
#
# [5 rows x 40 columns]

# %%
#We select the top 5 countries to create the area plot
top5 = dataset[years].head(5).transpose()
top5.head(10)
# Out:
# OdName  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980     8880   5123                                              22045
# 1981     8670   6682                                              24796
# 1982     8147   3308                                              20620
# 1983     7338   1863                                              10015
# 1984     5704   1527                                              10170
# 1985     4211   1816                                               9564
# 1986     7150   1960                                               9470
# 1987    10189   2643                                              21337
# 1988    11522   2758                                              27359
# 1989    10343   4323                                              23795
#
# OdName  Philippines  Pakistan
# 1980           6051       978
# 1981           5921       972
# 1982           5249      1201
# 1983           4562       900
# 1984           3801       668
# 1985           3150       514
# 1986           4166       691
# 1987           7360      1072
# 1988           8639      1334
# 1989          11865      2261

# %%
top5.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             figsize=(20, 10),)

plt.title('Immigration Trend of Top 5 Countries', size=18)
plt.ylabel('Number of Immigrants', size=15)
plt.xlabel('Years',size=15)
plt.legend(["India", "China", "UK", "Philippines", "Pakistan"])
plt.show();

# %% [markdown]
# # Horizontal Bar Chart
# ### Uses
# When there are a lot of categories.
# If the category labels are long.
#
# ### Tips
# Try to use one colour, except to highlight importand bars.
#
# Bars should be wider than the spaces.
#
# Write labels horizontally (flat).
#
# Order the labels consistantly.

# %%
#HORIZONTAL BAR CHART TO COMPARE IMMIGRATION - TOP 5

# Extract data from India and China (Top2)
data_CI = dataset.loc[['India','China'], years].transpose()
data_CI.reset_index(inplace=True)
data_CI.rename(columns={'index':'Year'},inplace=True)
data_CI.head()
# Out:
# OdName  Year  India  China
# 0       1980   8880   5123
# 1       1981   8670   6682
# 2       1982   8147   3308
# 3       1983   7338   1863
# 4       1984   5704   1527

# %%
ax0= data_CI.plot(kind='barh',  x='Year',figsize=(15, 10))

ax0.set_xlabel('Year', fontsize=12)
ax0.set_ylabel('Number of Immigrants India vs China',fontsize=12)
ax0.set_title('Immigration from top 2 countries between 1980 and 2013', fontsize=18)
plt.show();

# %% [markdown]
# # Vertical Bar Charts

# %%
#India bar chart

india = dataset.loc['India',years]

india.plot(kind='bar',figsize=(10,6), color='pink')
plt.xlabel('Years', fontsize = 12)
plt.ylabel('Number of Immigrants', fontsize = 12)
plt.title('Immigration from India', fontsize = 15)
plt.show();

# %% [markdown]
# # Histogram
# ### Like a bar chart, but for continuous data
# ### Tips
# Try to keep the columns the same width.
#
# Try to choose sensible binnings (where applicable).

# %%
#HISTOGRAM

dataset['2013'].plot(kind = 'hist', color = 'green', bins=5)


plt.title('Immigration in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')
plt.show();

# %%
#COMPARING TWO DIFFERENT PLOTS (SUBPLOTS)

plt.subplot(2, 2, 1)
dataset['2008'].plot(kind = 'hist', color = 'green')
plt.title('Immigration in 2008')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.subplot(2, 2, 4)
dataset['2010'].plot(kind = 'hist', color = 'green')
plt.title('Immigration in 2010')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.tight_layout(pad = 3.0)
plt.show();

# %% [markdown]
# # Scatter Plot
# ### Uses
# To show the relationship between variables.
#
# ### Tips
# When displaying a suspected causal relationship, have the "explanatory" variable on the x-axis.
#
# Can use colour and dot ("bubble") size to display more variables (ie in a bubble plot).

# %%
dataset[years].transpose().plot.scatter("Ireland", "United Kingdom of Great Britain and Northern Ireland")
plt.title('Immigrants from Ireland vs the UK')
plt.show();
